# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
global_regions_phasings_fam = np.loadtxt(
    '/home/groups/dpwall/briannac/alt_haplotypes/intermediate_files/family_likelihoods/ground_truth/global_regions_phasings_fam552.tsv', delimiter='\t')
likelihood_matrix_phasings_fam = np.loadtxt('/home/groups/dpwall/briannac/alt_haplotypes/intermediate_files/family_likelihoods/ground_truth/likelihood_matrix_phasings_kmers_fam552.tsv', 
                                        delimiter='\t', max_rows=1000, skiprows=10000)

# %%
L_fam = np.matmul(likelihood_matrix_phasings_fam[900,:],global_regions_phasings_fam.transpose())
np.savetxt('/home/groups/dpwall/briannac/alt_haplotypes/results/figures/L_example_fam.txt', L_fam)

# %%
plt.figure(figsize=(10,1.5))
plt.plot(L)
plt.axis('off')
plt.tight_layout()
plt.savefig('/home/groups/dpwall/briannac/alt_haplotypes/results/figures/L_example_fam.svg')
plt.show()

# %%
global_regions_phasings = np.loadtxt(
    '/home/groups/dpwall/briannac/alt_haplotypes/intermediate_files/family_likelihoods/ground_truth/global_regions_phasings.tsv', delimiter='\t')
likelihood_matrix_phasings = np.loadtxt('/home/groups/dpwall/briannac/alt_haplotypes/intermediate_files/family_likelihoods/ground_truth/likelihood_matrix_phasings_kmers.tsv', 
                                        delimiter='\t', max_rows=1000, skiprows=10000)

# %%
np.shape(likelihood_matrix_phasings)
# Out:
# (1000, 9001)

# %%
L_all = np.matmul(likelihood_matrix_phasings[900,:],global_regions_phasings.transpose())
np.savetxt('/home/groups/dpwall/briannac/alt_haplotypes/results/figures/L_example_all.txt', L_all)

# %%
L_all = np.loadtxt('/home/groups/dpwall/briannac/alt_haplotypes/results/figures/L_example_all.txt')

# %%
plt.figure(figsize=(10,1.5))
plt.plot(L_all)
plt.axis('off')
plt.tight_layout()
plt.savefig('/home/groups/dpwall/briannac/alt_haplotypes/results/figures/L_example_all.svg')
plt.show()
