# %%
import pandas as pd
import numpy as np
import sys
import glob 
from tqdm import tqdm

# %%
FINAL_PHASINGS_DIR='/home/groups/dpwall/briannac/alt_haplotypes/data/phasings/phased_fams'
fams = [g.split('/')[-1].replace('.txt', '') for g in glob.glob(
    FINAL_PHASINGS_DIR + '/*.txt')]
df = pd.read_table('%s/%s.txt' % (FINAL_PHASINGS_DIR, 'AU0022'))
if True:
    bam_mappings_file = '/home/groups/dpwall/briannac/general_data/bam_mappings.csv'
    bam_mappings = pd.read_csv(bam_mappings_file, sep='\t')
    bam_mappings.index = bam_mappings.participant_id
    sexes = pd.concat([bam_mappings.loc[[s.split('_')[0]]].iloc[[0]] for s in df.columns[2:-2]]).sex_numeric.values
    new_row = pd.DataFrame([0, 'chrY', 8, 9, 10, 11] + [10+2*(i%2)-int(float(s)) for i,s in enumerate(sexes[4:])] + [0,100]).transpose()
    new_row.columns = df.columns
    new_df = pd.concat([df, new_row])
    new_df.loc[
        (new_df.chrom=='chrX') & (new_df.end_pos>=2781479) & (new_df.start_pos<=155701383), 
        new_df.columns[2:-2]] = new_df.loc[
        (new_df.chrom=='chrX') & (new_df.end_pos>=2781479) & (new_df.start_pos<=155701383),
        new_df.columns[2:-2]]+4
    pat_columns = [c for c in new_df.columns if c.split('_pat')[0] in bam_mappings.index]
    pat_male_columns = [c for c in pat_columns if bam_mappings.loc[c.split('_pat')[0]].sex_numeric[0]=='1.0']
    new_df.loc[(new_df.chrom=='chrX') & (new_df.end_pos>=2781479) & (new_df.start_pos<=155701383),pat_male_columns] = 7

# %%
new_df
# Out:
#     Unnamed: 0 chrom AU002201_mat AU002201_pat AU002202_mat AU002202_pat  \
# 0            0  chr1            0            1            2            3
# 1            4  chr1            0            1            2            3
# 2            9  chr1            0            1            2            3
# 3         1577  chr1            0            1            2            3
# 4         2417  chr1            0            1            2            3
# ..         ...   ...          ...          ...          ...          ...
# 392     226958  chrX            4            5            6            7
# 393     228805  chrX            4            5            6            7
# 394     230339  chrX            4            5            6            7
# 395     230854  chrX            4            5            6            7
# 0            0  chrY            8            9           10           11
#
#     AU002205_mat AU002205_pat AU002203_mat AU002203_pat AU002204_mat  \
# ...

# %%
new_df
# Out:
#     Unnamed: 0 chrom AU001201_mat AU001201_pat AU001202_mat AU001202_pat  \
# 0            0  chr1            0            1            2            3
# 1            2  chr1            0            1            2            3
# 2         1190  chr1            0            1            2            3
# 3         1333  chr1            0            1            2            3
# 4         2014  chr1            0            1            2            3
# ..         ...   ...          ...          ...          ...          ...
# 195     213613  chrX            4            5            6            7
# 196     215430  chrX            4            5            6            7
# 197     215914  chrX            4            5            6            7
# 198     216204  chrX            4            5            6            7
# 0            0  chrY            8            9           10           11
#
#     AU001204_mat AU001204_pat AU001203_mat AU001203_pat  start_pos    end_pos
# ...

# %%
FINAL_PHASINGS_DIR='/home/groups/dpwall/briannac/alt_haplotypes/data/phasings/phased_fams'
fams = [g.split('/')[-1].replace('.txt', '') for g in glob.glob(
    FINAL_PHASINGS_DIR + '/*.txt')]
for FAMILY in tqdm(fams): 
    df = pd.read_table('%s/%s.txt' % (FINAL_PHASINGS_DIR, FAMILY))
    bam_mappings_file = '/home/groups/dpwall/briannac/general_data/bam_mappings.csv'
    bam_mappings = pd.read_csv(bam_mappings_file, sep='\t')
    bam_mappings.index = bam_mappings.participant_id
    sexes = pd.concat([bam_mappings.loc[[s.split('_')[0]]].iloc[[0]] for s in df.columns[2:-2]]).sex_numeric.values
    new_row = pd.DataFrame([0, 'chrY', 8, 9, 10, 11] + [10+2*(i%2)-int(float(s)) for i,s in enumerate(sexes[4:])] + [0,100]).transpose()
    new_row.columns = df.columns
    new_df = pd.concat([df, new_row])
    new_df.loc[
        (new_df.chrom=='chrX') & (new_df.end_pos>=2781479) & (new_df.start_pos<=155701383), 
        new_df.columns[2:-2]] = new_df.loc[
        (new_df.chrom=='chrX') & (new_df.end_pos>=2781479) & (new_df.start_pos<=155701383),
        new_df.columns[2:-2]]+4
    pat_columns = [c for c in new_df.columns if c.split('_pat')[0] in bam_mappings.index]
    pat_male_columns = [c for c in pat_columns if bam_mappings.loc[c.split('_pat')[0]].sex_numeric[0]=='1.0']
    new_df.loc[(new_df.chrom=='chrX') & (new_df.end_pos>=2781479) & (new_df.start_pos<=155701383),pat_male_columns] = 7
    new_df.to_csv('%s/%s_with_y.txt' % (FINAL_PHASINGS_DIR, FAMILY), index=None, sep='\t')
# Out:
#   0%|          | 0/732 [00:00<?, ?it/s]
#
#
#
#   0%|          | 2/732 [00:00<01:05, 11.18it/s]
#
#
#
#   1%|          | 4/732 [00:00<01:05, 11.10it/s]
#
#
#
#   1%|          | 6/732 [00:00<01:04, 11.20it/s]
#
#
#
#   1%|          | 8/732 [00:00<01:04, 11.22it/s]
#
#
#
#   1%|▏         | 10/732 [00:00<01:03, 11.38it/s]
#
#
#
#   2%|▏         | 12/732 [00:01<01:04, 11.17it/s]
#
#
#
#   2%|▏         | 14/732 [00:01<01:02, 11.54it/s]
#
#
#
#   2%|▏         | 16/732 [00:01<01:01, 11.62it/s]
#
#
#
#   2%|▏         | 18/732 [00:01<01:01, 11.57it/s]
#
#
#
#   3%|▎         | 20/732 [00:01<01:00, 11.70it/s]
#
#
#
#   3%|▎         | 22/732 [00:01<01:00, 11.79it/s]
#
#
#
#   3%|▎         | 24/732 [00:02<01:00, 11.62it/s]
#
#
#
#   4%|▎         | 26/732 [00:02<01:00, 11.75it/s]
#
#
#
#   4%|▍         | 28/732 [00:02<01:00, 11.66it/s]
#
#
#
#   4%|▍         | 30/732 [00:02<00:58, 11.94it/s]
#
#
#
#   4%|▍         | 32/732 [00:02<00:57, 12.09it/s]
#
#
#
# ...

# %%
'%s/%s.txt' % (FINAL_PHASINGS_DIR, FAMILY)
# Out:
# '/home/groups/dpwall/briannac/alt_haplotypes/data/phasings/phased_fams/AU1076_with_y.txt'

# %%
A = np.load('/home/groups/dpwall/briannac/alt_haplotypes/data/phasings/fam_region_to_idx.npy', allow_pickle=True).item()

# %%
# Format for PAR
new_df.loc[
    (new_df.chrom=='chrX') & (new_df.start_pos>=2781479) & (new_df.start_pos<=155701383), 
    new_df.columns[2:-2]] = new_df.loc[
    (new_df.chrom=='chrX') & (new_df.start_pos>=2781479) & (new_df.start_pos<=155701383),
    new_df.columns[2:-2]]+4

# %%
bam_mappings.loc[[s.split('_')[0] for s in df.columns[2:-2]]]
# Out:
#                                   status sample_id participant_id  family  \
# participant_id
# AU003701        Passed_QC_analysis_ready  03C15853       AU003701  AU0037
# AU003701        Passed_QC_analysis_ready  03C15853       AU003701  AU0037
# AU003702        Passed_QC_analysis_ready  03C15854       AU003702  AU0037
# AU003702        Passed_QC_analysis_ready  03C15854       AU003702  AU0037
# AU003705        Passed_QC_analysis_ready  03C14365       AU003705  AU0037
# AU003705        Passed_QC_analysis_ready  03C14365       AU003705  AU0037
# AU003704                HOLD:IBD_pending  02C11910       AU003704  AU0037
# AU003704        Passed_QC_analysis_ready  03C15856       AU003704  AU0037
# AU003704                HOLD:IBD_pending  02C11910       AU003704  AU0037
# AU003704        Passed_QC_analysis_ready  03C15856       AU003704  AU0037
# AU003703        Passed_QC_analysis_ready  03C15855       AU003703  AU0037
# ...

# %%
len(sexes)
# Out:
# 12

# %%
df
# Out:
#      Unnamed: 0 chrom  AU003701_mat  AU003701_pat  AU003702_mat  AU003702_pat  \
# 0             0  chr1             0             1             2             3
# 1             5  chr1             0             1             2             3
# 2           328  chr1             0             1             2             3
# 3          2576  chr1             0             1             2             3
# 4          2752  chr1             0             1             2             3
# ..          ...   ...           ...           ...           ...           ...
# 418      220222  chrX             0             1             2             3
# 419      221175  chrX             0             1             2             3
# 420      221260  chrX             0             1             2             3
# 421      221723  chrX             0             1             2             3
# 422      222558  chrX             0             1             2             3
#
# ...

# %%
new_row = pd.DataFrame([0, 'chrY', 0, 1, 2, 3] + [2*(i%2)+int(float(s))-1 for i,s in enumerate(sexes[4:])] + [0,100]).transpose()
new_row.columns = df.columns
new_df = pd.concat([df, new_row])
new_df.to_csv('%s/%s_with_y.txt' % (FINAL_PHASINGS_DIR, FAMILY), index=None)
# Out:
#     Unnamed: 0 chrom AU1286202_mat AU1286202_pat AU1286201_mat AU1286201_pat  \
# 0            0  chr1             0             1             2             3
# 1            4  chr1             0             1             2             3
# 2          318  chr1             0             1             2             3
# 3          531  chr1             0             1             2             3
# 4         4850  chr1             0             1             2             3
# ..         ...   ...           ...           ...           ...           ...
# 206     201582  chrX             0             1             2             3
# 207     202367  chrX             0             1             2             3
# 208     202992  chrX             0             1             2             3
# 209     203346  chrX             0             1             2             3
# 0            0  chrY             0             1             2             3
#
# ...

# %%
[0, 'chrX', 0, 1, 2, 3] + [2*(i%2)+int(float(s))-1 for i,s in enumerate(sexes[4:])]
# Out:
# [0, 'chrX', 0, 1, 2, 3, 0, 2, 0, 2]

# %%
df = pd.read_table('%s/%s.phased.txt' % (KELLEY_PHASINGS_DIR, FAMILY), skiprows=1, header=None)
cols = pd.read_table('%s/%s.phased.txt' % (KELLEY_PHASINGS_DIR, FAMILY), nrows=0).columns
df = df[list(df.columns[:len(cols)-2]) + list(df.columns[-2:])]
df.columns = cols
df.drop(['m1_del', 'm2_del', 'p1_del', 'p2_del', 'loss_region'], axis=1, inplace=True)


is_dup = False
prev_row = df.iloc[0][:-2]
start_idx = 0
idx_to_combine = []
for i,row in enumerate(df.iterrows()):
    if i==0: continue
    if (row[1][:-2]==prev_row).all():
        end_idx = i
        is_dup = True
    else:
        if is_dup:
            idx_to_combine = idx_to_combine + [(start_idx, end_idx)]
        is_dup = False
        start_idx = i
        prev_row = row[1][:-2]

# One last cycle through for last region of genome.
if is_dup:
    idx_to_combine = idx_to_combine + [(start_idx, end_idx)]
        
new_df = df.copy()
for start_idx, stop_idx in idx_to_combine:
    new_df.loc[start_idx,'end_pos']=new_df.iloc[stop_idx]['end_pos']
new_df = new_df.iloc[[i for i,_ in idx_to_combine]] 
new_df.to_csv('%s/%s.txt' % (FINAL_PHASINGS_DIR, FAMILY), sep='\t')
print(len(df), 'original rows')
print(len(new_df), 'rows in cleaned dataframe')

# %%
df
# Out:
#     chrom  AU3913202_mat  AU3913202_pat  AU3913201_mat  AU3913201_pat  \
# 0    chr1              0              1              2              3
# 1    chr1              0              1              2              3
# 2    chr1              0              1              2              3
# 3    chr1              0              1              2              3
# 4    chr1              0              1              2              3
# ..    ...            ...            ...            ...            ...
# 257  chr1              0              1              2              3
# 258  chr1              0              1              2              3
# 259  chr1              0              1              2              3
# 260  chr1              0              1              2              3
# 261  chr1              0              1              2              3
#
#      AU3913304_mat  AU3913304_pat  AU3913301_mat  AU3913301_pat  \
# ...
