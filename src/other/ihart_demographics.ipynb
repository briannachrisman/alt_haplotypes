# %%
from collections import Counter
import pandas as pd
bam_mappings = pd.read_table('/home/groups/dpwall/briannac/general_data/bam_mappings.csv', index_col=1)
bam_mappings = bam_mappings[bam_mappings.status=='Passed_QC_analysis_ready']
bam_mappings = bam_mappings.drop('09C86428')

# %%
a = bam_mappings.groupby('race').count()
a/a.sum()
# Out:
#                                              status  participant_id    family  \
# race
# american-indian-alaskan-native             0.003503        0.003503  0.003503
# asian                                      0.027802        0.027802  0.027802
# black-or-african-american                  0.029553        0.029553  0.029553
# more-than-one-race                         0.054291        0.054291  0.054291
# native-hawaiian-or-other-pacific-islander  0.006786        0.006786  0.006786
# unknown                                    0.042907        0.042907  0.042907
# white                                      0.835158        0.835158  0.835158
#
#                                            AGRE Blood  NIMH Blood  \
# race
# american-indian-alaskan-native               0.003503    0.003545
# asian                                        0.027802    0.028135
# black-or-african-american                    0.029553    0.028799
# more-than-one-race                           0.054291    0.054940
# native-hawaiian-or-other-pacific-islander    0.006786    0.006868
# unknown                                      0.042907    0.039211
# white                                        0.835158    0.838502
#
#                                            relationship  FatherID  MotherID  \
# race
# american-indian-alaskan-native                 0.003503  0.003503  0.003503
# asian                                          0.027802  0.027802  0.027802
# black-or-african-american                      0.029553  0.029553  0.029553
# more-than-one-race                             0.054291  0.054291  0.054291
# native-hawaiian-or-other-pacific-islander      0.006786  0.006786  0.006786
# unknown                                        0.042907  0.042907  0.042907
# white                                          0.835158  0.835158  0.835158
#
#                                            sex_numeric  \
# race
# american-indian-alaskan-native                0.003503
# asian                                         0.027802
# black-or-african-american                     0.029553
# more-than-one-race                            0.054291
# native-hawaiian-or-other-pacific-islander     0.006786
# unknown                                       0.042907
# white                                         0.835158
#
#                                            derived_affected_status  ...  \
# race                                                                ...
# american-indian-alaskan-native                            0.000923  ...
# asian                                                     0.022612  ...
# black-or-african-american                                 0.028150  ...
# more-than-one-race                                        0.080295  ...
# native-hawaiian-or-other-pacific-islander                 0.005999  ...
# unknown                                                   0.041071  ...
# white                                                     0.820951  ...
#
#                                            number_of_indels  \
# race
# american-indian-alaskan-native                          NaN
# asian                                                   NaN
# black-or-african-american                               NaN
# more-than-one-race                                      NaN
# native-hawaiian-or-other-pacific-islander               NaN
# unknown                                                 NaN
# white                                                   NaN
#
#                                            number_of_homozygous_snvs  \
# race
# american-indian-alaskan-native                                   NaN
# asian                                                            NaN
# black-or-african-american                                        NaN
# more-than-one-race                                               NaN
# native-hawaiian-or-other-pacific-islander                        NaN
# unknown                                                          NaN
# white                                                            NaN
#
#                                            number_of_heterozygous_snvs  \
# race
# american-indian-alaskan-native                                     NaN
# asian                                                              NaN
# black-or-african-american                                          NaN
# more-than-one-race                                                 NaN
# native-hawaiian-or-other-pacific-islander                          NaN
# unknown                                                            NaN
# white                                                              NaN
#
#                                            het_to_hom_ratio  ti_tv_ratio  \
# race
# american-indian-alaskan-native                          NaN          NaN
# asian                                                   NaN          NaN
# black-or-african-american                               NaN          NaN
# more-than-one-race                                      NaN          NaN
# native-hawaiian-or-other-pacific-islander               NaN          NaN
# unknown                                                 NaN          NaN
# white                                                   NaN          NaN
#
#                                            dbsnp_overlap  \
# race
# american-indian-alaskan-native                       NaN
# asian                                                NaN
# black-or-african-american                            NaN
# more-than-one-race                                   NaN
# native-hawaiian-or-other-pacific-islander            NaN
# unknown                                              NaN
# white                                                NaN
#
#                                            concordance_with_genotyping_chip  \
# race
# american-indian-alaskan-native                                          NaN
# asian                                                                   NaN
# black-or-african-american                                               NaN
# more-than-one-race                                                      NaN
# native-hawaiian-or-other-pacific-islander                               NaN
# unknown                                                                 NaN
# white                                                                   NaN
#
#                                            cryptic_relatedness_check  \
# race
# american-indian-alaskan-native                                   NaN
# asian                                                            NaN
# black-or-african-american                                        NaN
# more-than-one-race                                               NaN
# native-hawaiian-or-other-pacific-islander                        NaN
# unknown                                                          NaN
# white                                                            NaN
#
#                                            family_based_average_coverage  \
# race
# american-indian-alaskan-native                                       NaN
# asian                                                                NaN
# black-or-african-american                                            NaN
# more-than-one-race                                                   NaN
# native-hawaiian-or-other-pacific-islander                            NaN
# unknown                                                              NaN
# white                                                                NaN
#
#                                            familial_relationship_check
# race
# american-indian-alaskan-native                                     NaN
# asian                                                              NaN
# black-or-african-american                                          NaN
# more-than-one-race                                                 NaN
# native-hawaiian-or-other-pacific-islander                          NaN
# unknown                                                            NaN
# white                                                              NaN
#
# [7 rows x 72 columns]
